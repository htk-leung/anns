# %%
#%%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

def loaddata(filename):
    arr = np.loadtxt(filename, delimiter=',', skiprows=1)
    return {
        'd':                arr[:, 0],
        'efc':              arr[:, 1],
        'm':                arr[:, 2],
        'efs':              arr[:, 3],
        'k':                arr[:, 4],
        'recall':           arr[:, 5],
        'distcountconstr':  arr[:, 6],
        'distcountsearch':  arr[:, 7]
    }

xparam = "recall"
yparam1 = "distcountconstr"
yparam2 = "distcountsearch"


hnswsiftc = loaddata('data/20251002-hnsw-dist-cache-sift.txt')
hnswsiftnc = loaddata('data/20251002-hnsw-dist-nocache-sift.txt')
hnswrandc = loaddata('data/20251002-hnsw-dist-cache-gen.txt')
hnswrandnc = loaddata('data/20251002-hnsw-dist-nocache-gen.txt')

flatnavsift = loaddata('data/20251002-flatnav-sift.txt') #s100 c100
flatnavrand = loaddata('data/20251002-flatnav-gen.txt')  #s100 c100

flatnavsift5050 = loaddata('data/20251002-flatnav-sift-s50-c50.txt') #s50 c50
# flatnavrand5050 = loaddata('data/20251002-flatnav-gen-s50-c50.txt')  #s50 c50

flatnavsift50100 = loaddata('data/20251002-flatnav-sift-s50-c100.txt') #s50 c100
# flatnavrand50100 = loaddata('data/20251002-flatnav-gen-s50-c100.txt')  #s50 c100

flatnavsift50200 = loaddata('data/20251002-flatnav-sift-s50-c200.txt') #s50 c200
# flatnavrand50200 = loaddata('data/20251002-flatnav-gen-s50-c200.txt')  #s50 c200

flatnavsift10050 = loaddata('data/20251002-flatnav-sift-s100-c50.txt') #s100 c50
# flatnavrand10050 = loaddata('data/20251002-flatnav-gen-s100-c50.txt')  #s100 c50

flatnavsift100200 = loaddata('data/20251002-flatnav-sift-s100-c200.txt') #s100 c200
# flatnavrand100200 = loaddata('data/20251002-flatnav-gen-s100-c200.txt')  #s100 c200

flatnavsift20050 = loaddata('data/20251002-flatnav-sift-s200-c50.txt') #s200 c50
# flatnavrand20050 = loaddata('data/20251002-flatnav-gen-s200-c50.txt')  #s200 c50

flatnavsift200100 = loaddata('data/20251002-flatnav-sift-s200-c100.txt') #s200 c100
# flatnavrand200100 = loaddata('data/20251002-flatnav-gen-s200-c100.txt')  #s200 c100

flatnavsift200200 = loaddata('data/20251002-flatnav-sift-s200-c200.txt') #s200 c200
# flatnavrand200200 = loaddata('data/20251002-flatnav-gen-s200-c200.txt')  #s200 c200

flatnavsift10577 = loaddata('data/20251002-flatnav-sift-s105-c77.txt') #s105 c77

flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250
flatnavsiftRand1250 = loaddata('data/20251002-flatnav-sift-scRand1250.txt') #Random range 1-250

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# hnswsiftc = loaddata('20251002-hnsw-dist-cache-sift.txt')
# hnswsiftnc = loaddata('20251002-hnsw-dist-nocache-sift.txt')
# hnswrandc = loaddata('20251002-hnsw-dist-cache-gen.txt')
# hnswrandnc = loaddata('20251002-hnsw-dist-nocache-gen.txt')

# 1. hnsw, cache VS no cache, sift
x1 = hnswsiftc[xparam]
y1 = hnswsiftc[yparam1]
y1b = hnswsiftc[yparam2]
x2 = hnswsiftnc[xparam]
y2 = hnswsiftnc[yparam1]
y2b = hnswsiftnc[yparam2]

# create plot
fig1, ax1 = plt.subplots()

# set x-axis to logarithmic scale
#ax1.set_xscale('log') 

# plot
ax1.scatter(x1, y1, marker='x', color='red', s=50, label='cachec', alpha=0.2)
ax1.scatter(x2, y2, marker='x', color='blue', s=50, label='nocachec', alpha=0.2)

ax1.scatter(x1, y1b, marker='x', color='red', s=50, label='caches', alpha=0.8)
ax1.scatter(x2, y2b, marker='x', color='blue', s=50, label='nocaches', alpha=0.8)

# display
ax1.set_xlabel(xparam)
ax1.set_ylabel(f'{yparam1} / {yparam2}')
ax1.set_title(f'hnsw cache vs no cache')
ax1.legend()
ax1.grid(True, alpha=0.3)

#display graph
plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# hnswsiftc = loaddata('20251002-hnsw-dist-cache-sift.txt')
# hnswsiftnc = loaddata('20251002-hnsw-dist-nocache-sift.txt')
# hnswrandc = loaddata('20251002-hnsw-dist-cache-gen.txt')
# hnswrandnc = loaddata('20251002-hnsw-dist-nocache-gen.txt')

# 1s. hnsw, cache VS no cache, sift
x1 = hnswsiftc[xparam]
y1 = hnswsiftc[yparam1]
y1b = hnswsiftc[yparam2]
x2 = hnswsiftnc[xparam]
y2 = hnswsiftnc[yparam1]
y2b = hnswsiftnc[yparam2]

# create plot
fig1, ax1 = plt.subplots()

# set x-axis to logarithmic scale
#ax1.set_xscale('log') 

# plot

ax1.scatter(x1, y1b, marker='x', color='red', s=50, label='caches', alpha=0.8)
ax1.scatter(x2, y2b, marker='x', color='blue', s=50, label='nocaches', alpha=0.8)

# display
ax1.set_xlabel(xparam)
ax1.set_ylabel(f'{yparam2}')
ax1.set_title(f'hnsw cache vs no cache')
ax1.legend()
ax1.grid(True, alpha=0.3)

#display graph
plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# hnswrandc = loaddata('20251002-hnsw-dist-cache-gen.txt')
# hnswrandnc = loaddata('20251002-hnsw-dist-nocache-gen.txt')

# 2. hnsw sift vs rand
x1 = hnswsiftc[xparam]
y1 = hnswsiftc[yparam1]
y1b = hnswsiftc[yparam2]
x2 = hnswrandc[xparam]
y2 = hnswrandc[yparam1]
y2b = hnswrandc[yparam2]

#create plot
fig2, ax2 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax2.scatter(x1, y1, marker='x', color='red', s=50, label='siftc', alpha=0.2)
ax2.scatter(x2, y2, marker='x', color='blue', s=50, label='randc', alpha=0.2)

ax2.scatter(x1, y1b, marker='x', color='red', s=50, label='sifts', alpha=0.8)
ax2.scatter(x2, y2b, marker='x', color='blue', s=50, label='rands', alpha=0.8)

ax2.set_xlabel(xparam)
ax2.set_ylabel(f'{yparam1} / {yparam2}')
ax2.set_title(f'hnsw sift vs rand')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# hnswrandc = loaddata('20251002-hnsw-dist-cache-gen.txt')
# hnswrandnc = loaddata('20251002-hnsw-dist-nocache-gen.txt')

# 2s. hnsw sift vs rand
x1 = hnswsiftc[xparam]
y1 = hnswsiftc[yparam1]
y1b = hnswsiftc[yparam2]
x2 = hnswrandc[xparam]
y2 = hnswrandc[yparam1]
y2b = hnswrandc[yparam2]

#create plot
fig2, ax2 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax2.scatter(x1, y1b, marker='x', color='red', s=50, label='sifts', alpha=0.8)
ax2.scatter(x2, y2b, marker='x', color='blue', s=50, label='rands', alpha=0.8)

ax2.set_xlabel(xparam)
ax2.set_ylabel(f'{yparam2}')
ax2.set_title(f'hnsw sift vs rand')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountconstr"
# yparam2 = "distcountsearch"

# flatnavsift = loaddata('data/20251002-flatnav-sift.txt') #s100 c100
# flatnavrand = loaddata('data/20251002-flatnav-gen.txt')  #s100 c100

# 3. flatnav sift vs rand
x1 = flatnavsift[xparam]
y1 = flatnavsift[yparam1]
y1b = flatnavsift[yparam2]
x2 = flatnavrand[xparam]
y2 = flatnavrand[yparam1]
y2b = flatnavrand[yparam2]

#create plot
fig3, ax3 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax3.scatter(x1, y1, marker='x', color='red', s=50, label='siftc', alpha=0.2)
ax3.scatter(x2, y2, marker='x', color='blue', s=50, label='randc', alpha=0.2)

ax3.scatter(x1, y1b, marker='x', color='red', s=50, label='sifts', alpha=0.8)
ax3.scatter(x2, y2b, marker='x', color='blue', s=50, label='rands', alpha=0.8)

ax3.set_xlabel(xparam)
ax3.set_ylabel(f'{yparam1} / {yparam2}')
ax3.set_title(f'flatnav sift vs rand')
ax3.legend()
ax3.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountconstr"
# yparam2 = "distcountsearch"

# flatnavsift = loaddata('data/20251002-flatnav-sift.txt') #s100 c100
# flatnavrand = loaddata('data/20251002-flatnav-gen.txt')  #s100 c100

# 3s. flatnav sift vs rand
x1 = flatnavsift[xparam]
y1 = flatnavsift[yparam1]
y1b = flatnavsift[yparam2]
x2 = flatnavrand[xparam]
y2 = flatnavrand[yparam1]
y2b = flatnavrand[yparam2]

#create plot
fig3, ax3 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax3.scatter(x1, y1b, marker='x', color='red', s=50, label='sifts', alpha=0.8)
ax3.scatter(x2, y2b, marker='x', color='blue', s=50, label='rands', alpha=0.8)

ax3.set_xlabel(xparam)
ax3.set_ylabel(f'{yparam1} / {yparam2}')
ax3.set_title(f'flatnav sift vs rand')
ax3.legend()
ax3.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 4. hnsw cache VS flatnav cache
x1 = hnswsiftc[xparam]
y1 = hnswsiftc[yparam1]
y1b = hnswsiftc[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]

#create plot
fig4, ax4 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax4.scatter(x1, y1, marker='x', color='red', s=50, label='hnswc', alpha=0.2)
ax4.scatter(x2, y2, marker='x', color='blue', s=50, label='flatnavc', alpha=0.2)

ax4.scatter(x1, y1b, marker='x', color='red', s=50, label='hnsws', alpha=0.8)
ax4.scatter(x2, y2b, marker='x', color='blue', s=50, label='flatnavs', alpha=0.8)

ax4.set_xlabel(xparam)
ax4.set_ylabel(f'{yparam1} / {yparam2}')
ax4.set_title(f'hnsw vs flatnav on sift')
ax4.legend()
ax4.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 4s. hnsw cache VS flatnav cache
x1 = hnswsiftc[xparam]
y1 = hnswsiftc[yparam1]
y1b = hnswsiftc[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]

#create plot
fig4, ax4 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax4.scatter(x1, y1b, marker='x', color='red', s=50, label='hnsws', alpha=0.8)
ax4.scatter(x2, y2b, marker='x', color='blue', s=50, label='flatnavs', alpha=0.8)

ax4.set_xlabel(xparam)
ax4.set_ylabel(f'{yparam2}')
ax4.set_title(f'hnsw vs flatnav on sift')
ax4.legend()
ax4.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 5. flatnav 5050 VS 100100 VS 200200
x1 = flatnavsift5050[xparam]
y1 = flatnavsift5050[yparam1]
y1b = flatnavsift5050[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]
x3 = flatnavsift200200[xparam]
y3 = flatnavsift200200[yparam1]
y3b = flatnavsift200200[yparam2]

#create plot
fig5, ax5 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax5.scatter(x1, y1, marker='x', color='red', s=50, label='s50c50c', alpha=0.2)
ax5.scatter(x2, y2, marker='x', color='grey', s=50, label='s100c100c', alpha=0.2)
ax5.scatter(x3, y3, marker='x', color='blue', s=50, label='s200c200c', alpha=0.2)

ax5.scatter(x1, y1b, marker='x', color='red', s=50, label='s50c50s', alpha=0.8)
ax5.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)
ax5.scatter(x3, y3b, marker='x', color='blue', s=50, label='s200c200s', alpha=0.8)

ax5.set_xlabel(xparam)
ax5.set_ylabel(f'{yparam1} / {yparam2}')
ax5.set_title(f'flatnav init. num.')
ax5.legend()
ax5.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 5s. flatnav 5050 VS 100100 VS 200200
x1 = flatnavsift5050[xparam]
y1 = flatnavsift5050[yparam1]
y1b = flatnavsift5050[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]
x3 = flatnavsift200200[xparam]
y3 = flatnavsift200200[yparam1]
y3b = flatnavsift200200[yparam2]

#create plot
fig5, ax5 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax5.scatter(x1, y1b, marker='x', color='red', s=50, label='s50c50s', alpha=0.8)
ax5.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)
ax5.scatter(x3, y3b, marker='x', color='blue', s=50, label='s200c200s', alpha=0.8)

ax5.set_xlabel(xparam)
ax5.set_ylabel(f'{yparam2}')
ax5.set_title(f'flatnav init. num.')
ax5.legend()
ax5.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 6. flatnav increase search init num 50100 VS 100100 VS 200100
x1 = flatnavsift50100[xparam]
y1 = flatnavsift50100[yparam1]
y1b = flatnavsift50100[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]
x3 = flatnavsift200100[xparam]
y3 = flatnavsift200100[yparam1]
y3b = flatnavsift200100[yparam2]

#create plot
fig6, ax6 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax6.scatter(x1, y1, marker='x', color='red', s=50, label='s50c100c', alpha=0.2)
ax6.scatter(x2, y2, marker='x', color='grey', s=50, label='s100c100c', alpha=0.2)
ax6.scatter(x3, y3, marker='x', color='blue', s=50, label='s200c100c', alpha=0.2)

ax6.scatter(x1, y1b, marker='x', color='red', s=50, label='s50c100s', alpha=0.8)
ax6.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)
ax6.scatter(x3, y3b, marker='x', color='blue', s=50, label='s200c100s', alpha=0.8)

ax6.set_xlabel(xparam)
ax6.set_ylabel(f'{yparam1} / {yparam2}')
ax6.set_title(f'flatnav increase search init. num.')
ax6.legend()
ax6.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 6s. flatnav increase search init num 50100 VS 100100 VS 200100
x1 = flatnavsift50100[xparam]
y1 = flatnavsift50100[yparam1]
y1b = flatnavsift50100[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]
x3 = flatnavsift200100[xparam]
y3 = flatnavsift200100[yparam1]
y3b = flatnavsift200100[yparam2]

#create plot
fig6, ax6 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax6.scatter(x1, y1b, marker='x', color='red', s=50, label='s50c100s', alpha=0.8)
ax6.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)
ax6.scatter(x3, y3b, marker='x', color='blue', s=50, label='s200c100s', alpha=0.8)

ax6.set_xlabel(xparam)
ax6.set_ylabel(f'{yparam2}')
ax6.set_title(f'flatnav increase search init. num.')
ax6.legend()
ax6.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 7. flatnav increase constr init num 10050 VS 100100 VS 100200x1 = flatnavsift50100[xparam]
x1 = flatnavsift10050[xparam]
y1 = flatnavsift10050[yparam1]
y1b = flatnavsift10050[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]
x3 = flatnavsift100200[xparam]
y3 = flatnavsift100200[yparam1]
y3b = flatnavsift100200[yparam2]

#create plot
fig7, ax7 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax7.scatter(x1, y1, marker='x', color='red', s=50, label='s100c50c', alpha=0.2)
ax7.scatter(x2, y2, marker='x', color='grey', s=50, label='s100c100c', alpha=0.2)
ax7.scatter(x3, y3, marker='x', color='blue', s=50, label='s100c200c', alpha=0.2)

ax7.scatter(x1, y1b, marker='x', color='red', s=50, label='s100c50s', alpha=0.8)
ax7.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)
ax7.scatter(x3, y3b, marker='x', color='blue', s=50, label='s100c200s', alpha=0.8)

ax7.set_xlabel(xparam)
ax6.set_ylabel(f'{yparam1} / {yparam2}')
ax7.set_title(f'flatnav increase constr init. num.')
ax7.legend()
ax7.grid(True, alpha=0.3)

plt.show()

# %%
# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 7s. flatnav increase constr init num 10050 VS 100100 VS 100200x1 = flatnavsift50100[xparam]
x1 = flatnavsift10050[xparam]
y1 = flatnavsift10050[yparam1]
y1b = flatnavsift10050[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]
x3 = flatnavsift100200[xparam]
y3 = flatnavsift100200[yparam1]
y3b = flatnavsift100200[yparam2]

#create plot
fig7, ax7 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax7.scatter(x1, y1b, marker='x', color='red', s=50, label='s100c50s', alpha=0.8)
ax7.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)
ax7.scatter(x3, y3b, marker='x', color='blue', s=50, label='s100c200s', alpha=0.8)

ax7.set_xlabel(xparam)
ax6.set_ylabel(f'{yparam2}')
ax7.set_title(f'flatnav increase constr init. num.')
ax7.legend()
ax7.grid(True, alpha=0.3)

plt.show()

# %%
flatnavsift10577 = loaddata('data/20251002-flatnav-sift-s105-c77.txt') #s105 c77

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 8. flatnav 100100 vs non-divisible stepsizes
x1 = flatnavsift10577[xparam]
y1 = flatnavsift10577[yparam1]
y1b = flatnavsift10577[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]
x3 = flatnavsift10050[xparam]
y3 = flatnavsift10050[yparam1]
y3b = flatnavsift10050[yparam2]

#create plot
fig8, ax8 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax8.scatter(x1, y1, marker='x', color='red', s=50, label='s105c77c', alpha=0.2)
ax8.scatter(x2, y2, marker='x', color='grey', s=50, label='s100c100c', alpha=0.2)
ax8.scatter(x3, y3, marker='x', color='blue', s=50, label='s100c50c', alpha=0.2)

ax8.scatter(x1, y1b, marker='x', color='red', s=50, label='s105c77s', alpha=0.8)
ax8.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)
ax8.scatter(x3, y3b, marker='x', color='blue', s=50, label='s100c50s', alpha=0.8)

ax8.set_xlabel(xparam)
ax8.set_ylabel(f'{yparam1} / {yparam2}')
ax8.set_title(f'flatnav increase constr init. num.')
ax8.legend()
ax8.grid(True, alpha=0.3)

plt.show()

# %%
flatnavsift10577 = loaddata('data/20251002-flatnav-sift-s105-c77.txt') #s105 c77

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 8s. flatnav 100100 vs non-divisible stepsizes
x1 = flatnavsift10577[xparam]
y1 = flatnavsift10577[yparam1]
y1b = flatnavsift10577[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]
x3 = flatnavsift10050[xparam]
y3 = flatnavsift10050[yparam1]
y3b = flatnavsift10050[yparam2]

#create plot
fig8, ax8 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax8.scatter(x1, y1b, marker='x', color='red', s=50, label='s105c77s', alpha=0.8)
ax8.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)
ax8.scatter(x3, y3b, marker='x', color='blue', s=50, label='s100c50s', alpha=0.8)

ax8.set_xlabel(xparam)
ax8.set_ylabel(f'{yparam2}')
ax8.set_title(f'flatnav increase constr init. num.')
ax8.legend()
ax8.grid(True, alpha=0.3)

plt.show()

# %%
# flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
# flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
# flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250
# flatnavsiftRand1250 = loaddata('data/20251002-flatnav-sift-scRand1250.txt') #Random range 1-250

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 9. flatnav random
x0 = flatnavsiftRand1250[xparam]
y0 = flatnavsiftRand1250[yparam1]
y0b = flatnavsiftRand1250[yparam2]
x1 = flatnavsiftRand50[xparam]
y1 = flatnavsiftRand50[yparam1]
y1b = flatnavsiftRand50[yparam2]
x2 = flatnavsiftRand50150[xparam]
y2 = flatnavsiftRand50150[yparam1]
y2b = flatnavsiftRand50150[yparam2]
x3 = flatnavsiftRand150250[xparam]
y3 = flatnavsiftRand150250[yparam1]
y3b = flatnavsiftRand150250[yparam2]
x4 = flatnavsift[xparam]
y4 = flatnavsift[yparam1]
y4b = flatnavsift[yparam2]


#create plot
fig9, ax9 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 
ax9.scatter(x0, y0, marker='x', color='green', s=50, label='rand-1-250c', alpha=0.2)
ax9.scatter(x1, y1, marker='x', color='red', s=50, label='rand-1-50c', alpha=0.2)
ax9.scatter(x2, y2, marker='x', color='purple', s=50, label='rand-50-150c', alpha=0.2)
ax9.scatter(x3, y3, marker='x', color='blue', s=50, label='rand-150-250c', alpha=0.2)
ax9.scatter(x4, y4, marker='x', color='grey', s=50, label='s100c100c', alpha=0.2)

ax9.scatter(x0, y0b, marker='x', color='green', s=50, label='rand-1-250s', alpha=0.8)
ax9.scatter(x1, y1b, marker='x', color='red', s=50, label='rand-1-50s', alpha=0.8)
ax9.scatter(x2, y2b, marker='x', color='purple', s=50, label='rand-50-150s', alpha=0.8)
ax9.scatter(x3, y3b, marker='x', color='blue', s=50, label='rand-150-250s', alpha=0.8)
ax9.scatter(x4, y4b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)

ax9.set_xlabel(xparam)
ax9.set_ylabel(f'{yparam1} / {yparam2}')
ax9.set_title(f'flatnav random init. num. in specified range')
ax9.legend()
ax9.grid(True, alpha=0.3)

plt.show()

# %%
# flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
# flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
# flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250
# flatnavsiftRand1250 = loaddata('data/20251002-flatnav-sift-scRand1250.txt') #Random range 1-250

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 9s. flatnav random
x0 = flatnavsiftRand1250[xparam]
y0 = flatnavsiftRand1250[yparam1]
y0b = flatnavsiftRand1250[yparam2]
x1 = flatnavsiftRand50[xparam]
y1 = flatnavsiftRand50[yparam1]
y1b = flatnavsiftRand50[yparam2]
x2 = flatnavsiftRand50150[xparam]
y2 = flatnavsiftRand50150[yparam1]
y2b = flatnavsiftRand50150[yparam2]
x3 = flatnavsiftRand150250[xparam]
y3 = flatnavsiftRand150250[yparam1]
y3b = flatnavsiftRand150250[yparam2]
x4 = flatnavsift[xparam]
y4 = flatnavsift[yparam1]
y4b = flatnavsift[yparam2]


#create plot
fig9, ax9 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax9.scatter(x0, y0b, marker='x', color='green', s=50, label='rand-1-250s', alpha=0.8)
ax9.scatter(x1, y1b, marker='x', color='red', s=50, label='rand-1-50s', alpha=0.8)
ax9.scatter(x2, y2b, marker='x', color='purple', s=50, label='rand-50-150s', alpha=0.8)
ax9.scatter(x3, y3b, marker='x', color='blue', s=50, label='rand-150-250s', alpha=0.8)
ax9.scatter(x4, y4b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)

ax9.set_xlabel(xparam)
ax9.set_ylabel(f'{yparam2}')
ax9.set_title(f'flatnav random init. num. in specified range')
ax9.legend()
ax9.grid(True, alpha=0.3)

plt.show()

# %%
# flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
# flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
# flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 10. flatnav 100100 vs non-divisible stepsizes
x1 = flatnavsiftRand50[xparam]
y1 = flatnavsiftRand50[yparam1]
y1b = flatnavsiftRand50[yparam2]
x2 = flatnavsift5050[xparam]
y2 = flatnavsift5050[yparam1]
y2b = flatnavsift5050[yparam2]

#create plot
fig10, ax10 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax10.scatter(x1, y1, marker='x', color='red', s=50, label='rand-1-50c', alpha=0.2)
ax10.scatter(x2, y2, marker='x', color='grey', s=50, label='s50c50c', alpha=0.2)

ax10.scatter(x1, y1b, marker='x', color='red', s=50, label='rand-1-50s', alpha=0.8)
ax10.scatter(x2, y2b, marker='x', color='grey', s=50, label='s50c50s', alpha=0.8)

ax10.set_xlabel(xparam)
ax10.set_ylabel(f'{yparam1} / {yparam2}')
ax10.set_title(f'flatnav init. num. random vs static')
ax10.legend()
ax10.grid(True, alpha=0.3)

plt.show()

# %%
# flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
# flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
# flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 10s. flatnav 100100 vs non-divisible stepsizes
x1 = flatnavsiftRand50[xparam]
y1 = flatnavsiftRand50[yparam1]
y1b = flatnavsiftRand50[yparam2]
x2 = flatnavsift5050[xparam]
y2 = flatnavsift5050[yparam1]
y2b = flatnavsift5050[yparam2]

#create plot
fig10, ax10 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax10.scatter(x1, y1b, marker='x', color='red', s=50, label='rand-1-50s', alpha=0.8)
ax10.scatter(x2, y2b, marker='x', color='grey', s=50, label='s50c50s', alpha=0.8)

ax10.set_xlabel(xparam)
ax10.set_ylabel(f'{yparam2}')
ax10.set_title(f'flatnav init. num. random vs static')
ax10.legend()
ax10.grid(True, alpha=0.3)

plt.show()

# %%
# flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
# flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
# flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 11. flatnav 100100 vs non-divisible stepsizes
x1 = flatnavsiftRand50150[xparam]
y1 = flatnavsiftRand50150[yparam1]
y1b = flatnavsiftRand50150[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]

#create plot
fig11, ax11 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax11.scatter(x1, y1, marker='x', color='red', s=50, label='rand-50-150c', alpha=0.2)
ax11.scatter(x2, y2, marker='x', color='grey', s=50, label='s100c100c', alpha=0.2)

ax11.scatter(x1, y1b, marker='x', color='red', s=50, label='rand-50-150s', alpha=0.8)
ax11.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)

ax11.set_xlabel(xparam)
ax11.set_ylabel(f'{yparam1} / {yparam2}')
ax11.set_title(f'flatnav init. num. random vs static')
ax11.legend()
ax11.grid(True, alpha=0.3)

plt.show()

# %%
# flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
# flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
# flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 11s. flatnav 100100 vs non-divisible stepsizes
x1 = flatnavsiftRand50150[xparam]
y1 = flatnavsiftRand50150[yparam1]
y1b = flatnavsiftRand50150[yparam2]
x2 = flatnavsift[xparam]
y2 = flatnavsift[yparam1]
y2b = flatnavsift[yparam2]

#create plot
fig11, ax11 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax11.scatter(x1, y1b, marker='x', color='red', s=50, label='rand-50-150s', alpha=0.8)
ax11.scatter(x2, y2b, marker='x', color='grey', s=50, label='s100c100s', alpha=0.8)

ax11.set_xlabel(xparam)
ax11.set_ylabel(f'{yparam2}')
ax11.set_title(f'flatnav init. num. random vs static')
ax11.legend()
ax11.grid(True, alpha=0.3)

plt.show()

# %%
# flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
# flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
# flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 12. flatnav 100100 vs non-divisible stepsizes
x1 = flatnavsiftRand150250[xparam]
y1 = flatnavsiftRand150250[yparam1]
y1b = flatnavsiftRand150250[yparam2]
x2 = flatnavsift200200[xparam]
y2 = flatnavsift200200[yparam1]
y2b = flatnavsift200200[yparam2]

#create plot
fig12, ax12 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax12.scatter(x1, y1, marker='x', color='red', s=50, label='rand-150-250c', alpha=0.2)
ax12.scatter(x2, y2, marker='x', color='grey', s=50, label='s200c200c', alpha=0.2)

ax12.scatter(x1, y1b, marker='x', color='red', s=50, label='rand-150-250s', alpha=0.8)
ax12.scatter(x2, y2b, marker='x', color='grey', s=50, label='s200c200s', alpha=0.8)

ax12.set_xlabel(xparam)
ax12.set_ylabel(f'{yparam1} / {yparam2}')
ax12.set_title(f'flatnav init. num. random vs static')
ax12.legend()
ax12.grid(True, alpha=0.3)

plt.show()

# %%
# flatnavsiftRand50 = loaddata('data/20251002-flatnav-sift-scRand50.txt') #Random range 1-50
# flatnavsiftRand50150 = loaddata('data/20251002-flatnav-sift-scRand50150.txt') #Random range 50-150
# flatnavsiftRand150250 = loaddata('data/20251002-flatnav-sift-scRand150250.txt') #Random range 150-250

# xparam = "recall"
# yparam1 = "distcountsearch"
# yparam1 = "distcountconstr"

# 12s. flatnav 100100 vs non-divisible stepsizes
x1 = flatnavsiftRand150250[xparam]
y1 = flatnavsiftRand150250[yparam1]
y1b = flatnavsiftRand150250[yparam2]
x2 = flatnavsift200200[xparam]
y2 = flatnavsift200200[yparam1]
y2b = flatnavsift200200[yparam2]

#create plot
fig12, ax12 = plt.subplots()

# Set x-axis to logarithmic scale
#ax2.set_xscale('log') 

ax12.scatter(x1, y1b, marker='x', color='red', s=50, label='rand-150-250s', alpha=0.8)
ax12.scatter(x2, y2b, marker='x', color='grey', s=50, label='s200c200s', alpha=0.8)

ax12.set_xlabel(xparam)
ax12.set_ylabel(f'{yparam2}')
ax12.set_title(f'flatnav init. num. random vs static')
ax12.legend()
ax12.grid(True, alpha=0.3)

plt.show()
